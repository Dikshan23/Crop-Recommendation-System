# %%
sns.pairplot(
    df,
    vars=["N", "P", "K", "temperature", "humidity", "ph", "rainfall"],
    hue="label",
    diag_kind="kde"
)
plt.show()


#2
grouped = df.groupby("label").mean()

grouped.plot(kind="line", figsize=(12,6))
plt.title("Average Feature Values per Crop")
plt.ylabel("Mean Value")
plt.show()


#3
print("Skewness:")
print(df.drop(columns=["label"]).skew())

print("\nKurtosis:")
print(df.drop(columns=["label"]).kurtosis())
